# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.python.keras.layers.core import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # Load dữ liệu test

# %%
data = pd.read_csv('/content/drive/MyDrive/SwarmLearn/Cardio/Dataset/Test.csv')
y_test = data.iloc[: , -1]
X_test = data.iloc[: , :-1]
num_records = X_test.shape[0]
X_test = tf.constant(X_test.values[:,0:187])
X_test = tf.reshape(X_test, (num_records, 187, 1))

y_test = tf.one_hot(y_test.values, 2)
y_test = tf.reshape(y_test, (num_records, 2))

# %% [markdown]
# # Dữ liệu bị lật: User1 10%, User2 20%, User3 30%

# %% [markdown]
# ## User1

# %%
import tensorflow as tf
from tensorflow import keras
# Load the model from the .pb file
model = keras.models.load_model('/content/drive/MyDrive/SwarmLearn/Cardio/User1/Model_mitbih.pb')

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate= 0.01)
model.compile(
            loss='categorical_crossentropy',
            optimizer=optimizer,
            metrics=["accuracy"]
        )

# %%
y_pred = model.predict(X_test)
# Out:
# 917/917 [==============================] - 5s 5ms/step

# %%
y_test = np.argmax(y_test, axis=1)
y_pred= np.argmax(y_pred, axis=1)


# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y_test, y_pred)
print("Recall:", recall)

# Calculate F1-score
f1score = f1_score(y_test, y_pred)
print("F1-score:", f1score)
# Out:
# Accuracy: 0.9585407432662802
# Precision: 0.8516956920256645
# Recall: 0.9194537898278251
# F1-score: 0.8842786448420251

# %% [markdown]
# ## User 2

# %%
import tensorflow as tf
from tensorflow import keras
# Load the model from the .pb file
model = keras.models.load_model('/content/drive/MyDrive/SwarmLearn/Cardio/User2/Model_mitbih.pb')

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate= 0.01)
model.compile(
            loss='categorical_crossentropy',
            optimizer=optimizer,
            metrics=["accuracy"]
        )

# %%
y_pred = model.predict(X_test)
# Out:
# 917/917 [==============================] - 4s 5ms/step

# %%
y_test = np.argmax(y_test, axis=1)
y_pred= np.argmax(y_pred, axis=1)


# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y_test, y_pred)
print("Recall:", recall)

# Calculate F1-score
f1score = f1_score(y_test, y_pred)
print("F1-score:", f1score)
# Out:
# Accuracy: 0.9585407432662802
# Precision: 0.8516956920256645
# Recall: 0.9194537898278251
# F1-score: 0.8842786448420251

# %% [markdown]
# ## User 3

# %%
import tensorflow as tf
from tensorflow import keras
# Load the model from the .pb file
model = keras.models.load_model('/content/drive/MyDrive/SwarmLearn/Cardio/User3/Model_mitbih.pb')

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate= 0.01)
model.compile(
            loss='categorical_crossentropy',
            optimizer=optimizer,
            metrics=["accuracy"]
        )

# %%
y_pred = model.predict(X_test)
# Out:
# 917/917 [==============================] - 4s 4ms/step

# %%
y_test = np.argmax(y_test, axis=1)
y_pred= np.argmax(y_pred, axis=1)


# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y_test, y_pred)
print("Recall:", recall)

# Calculate F1-score
f1score = f1_score(y_test, y_pred)
print("F1-score:", f1score)
# Out:
# Accuracy: 0.9585407432662802
# Precision: 0.8516956920256645
# Recall: 0.9194537898278251
# F1-score: 0.8842786448420251

# %% [markdown]
# # Dữ liệu bình thường

# %%
data = pd.read_csv('/content/drive/MyDrive/SwarmLearn/Cardio/Flip_data/PC1.csv')
y_test = data.iloc[: , -1]
X_test = data.iloc[: , :-1]
num_records = X_test.shape[0]
X_test = tf.constant(X_test.values[:,0:187])
X_test = tf.reshape(X_test, (num_records, 187, 1))

y_test = tf.one_hot(y_test.values, 2)
y_test = tf.reshape(y_test, (num_records, 2))

# %% [markdown]
# ## User 1

# %%
import tensorflow as tf
from tensorflow import keras
# Load the model from the .pb file
model = keras.models.load_model('/content/drive/MyDrive/SwarmLearn/Cardio/User1/Model_mitbih.pb')

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate= 0.01)
model.compile(
            loss='categorical_crossentropy',
            optimizer=optimizer,
            metrics=["accuracy"]
        )

# %%
y_pred = model.predict(X_test)
y_test = np.argmax(y_test, axis=1)
y_pred= np.argmax(y_pred, axis=1)


# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y_test, y_pred)
print("Recall:", recall)

# Calculate F1-score
f1score = f1_score(y_test, y_pred)
print("F1-score:", f1score)
# Out:
# 917/917 [==============================] - 5s 5ms/step
# Accuracy: 0.9643697364383375
# Precision: 0.8678171470534239
# Recall: 0.9356690419635788
# F1-score: 0.9004667111153444

# %% [markdown]
# ## User 2

# %%
import tensorflow as tf
from tensorflow import keras
# Load the model from the .pb file
model = keras.models.load_model('/content/drive/MyDrive/SwarmLearn/Cardio/User2/Model_mitbih.pb')

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate= 0.01)
model.compile(
            loss='categorical_crossentropy',
            optimizer=optimizer,
            metrics=["accuracy"]
        )

# %%
y_pred = model.predict(X_test)
y_test = np.argmax(y_test, axis=1)
y_pred= np.argmax(y_pred, axis=1)


# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y_test, y_pred)
print("Recall:", recall)

# Calculate F1-score
f1score = f1_score(y_test, y_pred)
print("F1-score:", f1score)
# Out:
# 917/917 [==============================] - 4s 4ms/step
# Accuracy: 0.9643697364383375
# Precision: 0.8678171470534239
# Recall: 0.9356690419635788
# F1-score: 0.9004667111153444

# %% [markdown]
# ## User 3

# %%
import tensorflow as tf
from tensorflow import keras
# Load the model from the .pb file
model = keras.models.load_model('/content/drive/MyDrive/SwarmLearn/Cardio/User3/Model_mitbih.pb')

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate= 0.01)
model.compile(
            loss='categorical_crossentropy',
            optimizer=optimizer,
            metrics=["accuracy"]
        )

# %%
y_pred = model.predict(X_test)
y_test = np.argmax(y_test, axis=1)
y_pred= np.argmax(y_pred, axis=1)


# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y_test, y_pred)
print("Recall:", recall)

# Calculate F1-score
f1score = f1_score(y_test, y_pred)
print("F1-score:", f1score)
# Out:
# 917/917 [==============================] - 6s 6ms/step
# Accuracy: 0.9643697364383375
# Precision: 0.8678171470534239
# Recall: 0.9356690419635788
# F1-score: 0.9004667111153444
