# %% [markdown]
# # Import

# %%
MOUNT_POINT = '/content/drive'
from google.colab import drive
drive.mount(MOUNT_POINT, force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
from torchvision import datasets, transforms
import torchvision.models as models
import torchvision
from torchsummary import summary
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.utils import to_categorical

# %%
# Load dữ liệu
def load_data(path, test = True,r = 1, agents = 1):
  X = pd.read_csv(path)
  Y = X.iloc[:, -1:]
  num_records = Y.shape[0]
  X = tf.constant(X.values[:, 0:784])
  X = tf.reshape(X, (num_records, 784, 1))
    #X = tf.reshape(X, (num_records, 28, 28, 1))
  Y = tf.one_hot(Y.values[:, 0:], 2)
  Y = tf.reshape(Y, (num_records, 2))
  return X, Y

# %%
path = ('/content/drive/MyDrive/SwarmLearn/COVID19/COVID-19_Radiography_Dataset/test.csv')
X_test, Y_test = load_data(path)

# %% [markdown]
# # User 1

# %%
model1 = tf.keras.models.load_model("/content/drive/MyDrive/SwarmLearn/COVID19/User1/Model_covid/")

# %%
from keras.optimizers import SGD
sgd = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(loss = 'binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
y_pred = model1.predict(X_test)
# Out:
# 143/143 [==============================] - 1s 8ms/step

# %%
Y_test = np.argmax(Y_test, axis=1)
y_pred= np.argmax(y_pred, axis=1)

# Calculate accuracy
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(Y_test, y_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(Y_test, y_pred)
print("Recall:", recall)

# Calculate F1-score
f1score = f1_score(Y_test, y_pred)
print("F1-score:", f1score)
# Out:
# Accuracy: 0.8435508679411119
# Precision: 0.8547847423600268
# Recall: 0.9843308502440278
# F1-score: 0.9149952244508118

# %% [markdown]
# # User 2

# %%
model2 = tf.keras.models.load_model("/content/drive/MyDrive/SwarmLearn/COVID19/User2/Model_covid/")

# %%
from keras.optimizers import SGD
sgd = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(loss = 'binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
y_pred = model2.predict(X_test)
# Out:
# 143/143 [==============================] - 1s 7ms/step

# %%
Y_test = np.argmax(Y_test, axis=1)
y_pred= np.argmax(y_pred, axis=1)

# Calculate accuracy
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(Y_test, y_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(Y_test, y_pred)
print("Recall:", recall)

# Calculate F1-score
f1score = f1_score(Y_test, y_pred)
print("F1-score:", f1score)
# Out:
# Accuracy: 0.8585237258347979
# Precision: 0.8662081207011316
# Recall: 0.9896070975918885
# F1-score: 0.9238050165641268

# %% [markdown]
# # User 3

# %%
model3 = tf.keras.models.load_model("/content/drive/MyDrive/SwarmLearn/COVID19/User3/Model_covid/")

# %%
from keras.optimizers import SGD
sgd = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(loss = 'binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
y_pred = model3.predict(X_test)
# Out:
# 143/143 [==============================] - 3s 19ms/step

# %%
Y_test = np.argmax(Y_test, axis=1)
y_pred= np.argmax(y_pred, axis=1)

# Calculate accuracy
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(Y_test, y_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(Y_test, y_pred)
print("Recall:", recall)

# Calculate F1-score
f1score = f1_score(Y_test, y_pred)
print("F1-score:", f1score)
# Out:
# Accuracy: 0.8437705998681608
# Precision: 0.8623956688472818
# Recall: 0.9742609582059123
# F1-score: 0.9149216225918392
